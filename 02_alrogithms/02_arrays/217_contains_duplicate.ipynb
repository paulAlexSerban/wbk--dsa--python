# %% [markdown]
# # Contains Duplicate
# > Difficulty: Easy
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example 1:
# - Input: nums = [1,2,3,1]
# - Output: true
# Explanation: The element 1 occurs at the indices 0 and 3.
#
# Example 2:
# - Input: nums = [1,2,3,4]
# - Output: false
# Explanation: All elements are distinct.
#
# All elements are distinct.
#
# Example 3:
# - Input: nums = [1,1,1,3,3,4,3,2,4,2]
# - Output: true
# Explanation: The elements 1 and 3 occur multiple times.
#
# Constraints:
# - 1 <= nums.length <= 105
# - -109 <= nums[i] <= 109

# %%
from typing import List

def contains_duplicate(nums: List[int]) -> bool:
    """
    Check if the array contains any duplicates.

    :param nums: List of integers
    :return: True if duplicates are found, False otherwise
    """
    return   len(nums) != len(set(nums))

# %%
import unittest


class TestNotebook(unittest.TestCase):
    def test_contais_duplicate_1(self):
        self.assertEqual(contains_duplicate([1, 2, 3, 1]), True)

    def test_contains_duplicate_example_2(self):
        self.assertEqual(contains_duplicate([1, 2, 3, 4]), False)

    def test_contains_duplicate_example_3(self):
        self.assertEqual(contains_duplicate([1, 1, 1, 3, 3, 4, 3, 2, 4, 2]), True)

    def test_contains_duplicate_empty_list(self):
        self.assertEqual(contains_duplicate([]), False)

    def test_contains_duplicate_single_element(self):
        self.assertEqual(contains_duplicate([1]), False)


unittest.main(argv=[""], verbosity=2, exit=False)
# Out:
# test_contains_duplicate_empty_list (__main__.TestNotebook.test_contains_duplicate_empty_list) ... ok
# test_contains_duplicate_example_2 (__main__.TestNotebook.test_contains_duplicate_example_2) ... ok
# test_contains_duplicate_example_3 (__main__.TestNotebook.test_contains_duplicate_example_3) ... ok
# test_contains_duplicate_single_element (__main__.TestNotebook.test_contains_duplicate_single_element) ... ok
# test_contais_duplicate_1 (__main__.TestNotebook.test_contais_duplicate_1) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.006s
#
# OK
